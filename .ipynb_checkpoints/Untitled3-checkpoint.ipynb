# %%
# %load_ext autoreload

# %autoreload 4
from sqlalchemy import Table, Column, String, Integer, Float, Boolean, MetaData, insert, select, BIGINT, Date, DateTime, VARCHAR
from util import *
# Out:
# Using TensorFlow backend.

# %%
engine = get_engine(production=True)

# %%
pd.read_sql_query("SELECT * FROM MWS_COLT_ITEM LIMIT 3",  engine)

# %%
tmp_df = pd.read_sql_query("SELECT * FROM MWS_COLT_ITEM WHERE COLLECT_DAY > 2018-02-18",  engine)

# %%
tmp_df.head()
# Out:
#    ID GOODS_NUM  ITEM_NUM                        GOODS_NAME                                         GOODS_CATE BRAND_NAME  RELEASE_DT COLLECT_DAY SELL_CLOSE_DT ORG_MAFT_DT     MAFT_DT MAFT_ORIGIN    COLLECT_SITE PRICE_STD_CODE  PRICE  SITE_PRICE COLOR_OPTION SIZE_OPTION STYLE_OPTION GIFT_OPTION OPTION                                        COLLECT_URL  BEST_ITEM_YN BEST_ITEM_REG_DAY SITE_NAME      MATERIALS DESCR                                           ADD_INFO DETAIL_INFO                   TAG SIZE_FIT INGREDIENTS VOLUME TYPE                                            ORG_URL TRUST_SELLER  STORE_COLLECT_DATA_ID USE_WAY AVG_POINT  TOTAL_EVAL_CNT     STOCK_DETECT_DT  STOCK_CHANGE_YN  STATUS              REG_DT  REG_ID              UPT_DT  UPT_ID
# 0   1  K172101A  26824625     [에프엔] F.N 데일리 셔링 원피스 K172101A  패션의류/속옷>여성의류>원피스/정장세트>기본/정장;패션의류/속옷>여성의류>티셔츠>라...       ef.n  2017-08-01  2017-08-01    2017-09-15        None  2017-01-01              www.gsshop.com            001   7900        7900         (색상)       (사이즈)        (스타일)  (사은품/추가구성)         http://www.gsshop.com/deal/deal.gs?dealNo=2723...             0              None    GSSHOP                                                                                                               None               None   01  /app/ec/wspider/data/html/www.gsshop.com/26824...                                  -1       A       0.0               0 2017-08-09 04:08:07                0       1 2017-08-01 16:04:32  SERVER 2017-09-15 06:30:09  SERVER
# 1   2  K172101B  26824626  [에프엔] F.N 레이디 슬리브리스 원피스 K172101B  패션의류/속옷>여성의류>원피스/정장세트>기본/정장;패션의류/속옷>여성의류>티셔츠>라...       ef.n  2017-08-01  2017-08-01    2017-09-18      201701  2017-01-01       중국OEM  www.gsshop.com            001   7900        7900         (색상)       (사이즈)                                  http://www.gsshop.com/prd/prd.gs?prdid=2682462...             0              None    GSSHOP  겉감: 폴리에스터100%        {"A\/S 책임자와 전화번호":"GSSHOP 고객센터 1899-4500","제조국...              #50,000원 이상 구매시 무료배송     None               None   01  /app/ec/wspider/data/html/www.gsshop.com/26824...                                  -1       A       4.8               0 2017-08-09 03:59:11                0       1 2017-08-01 16:04:32  SERVER 2017-09-18 02:18:57  SERVER
# 2   3  K172401C  26824923     [에프엔] F.N 오피스 노카라 자켓 K172401C  패션의류/속옷>여성의류>재킷/점퍼>테일러드/기본;패션의류/속옷>여성의류>티셔츠>라운...       ef.n  2017-08-01  2017-08-01          None        None  2017-01-01              www.gsshop.com            001   7900        7900         (색상)       (사이즈)        (스타일)  (사은품/추가구성)         http://www.gsshop.com/deal/deal.gs?dealNo=2723...             0              None    GSSHOP                                                                                                               None               None   01  /app/ec/wspider/data/html/www.gsshop.com/26824...                                  -1       A       0.0               0 2017-08-25 00:35:36                0       1 2017-08-01 16:04:32  SERVER 2017-09-07 04:51:35  SERVER
