# %%
# %load_ext autoreload

# %autoreload 2

from util import *

# %%
engine = create_engine("mysql://wspider:wspider00!q@133.186.143.65:3306/wspider", connect_args={'connect_timeout': 10000})

# %%
mws_colt_item = pd.read_sql_query("SELECT * FROM MWS_COLT_ITEM WHERE RELEASE_DT > '2017-10-01' LIMIT 1000", engine)

# %%
mws_colt_item_ids = pd.read_sql_query("SELECT ID FROM MWS_COLT_ITEM WHERE RELEASE_DT > '2017-10-01'", engine)

# %%
mws_colt_item_ids_sample = np.random.choice(mws_colt_item_ids.ID.values, size=len(mws_colt_item_ids) / 100)

# %%
len(mws_colt_item_ids_sample)
# Out:
# 25041

# %%
# save output data as a pickle data format

# %%
favorite_color = pickle.load( open( "data/MWS_COLT_ITEM_IVT.p", "rb" ) )

# %%
stock_id_infO_df = pd.DataFrame(stock_id_info_lst)

# %%
import seaborn as sns

# %%
n_unique_stock_ids
# Out:
# 0        5
# 1        2
# 2        5
# 3        4
# 4        1
#         ..
# 34814    4
# 34815    6
# 34816    1
# 34817    1
# 34818    1
# Name: n_unique_stock_id, dtype: int64

# %%
plt.hist(n_unique_stock_ids, bins=1000)
plt.xlim((0, 100))
plt.show()

# %%
stock_id_infO_df[stock_id_infO_df['n_unique_stock_id'] > 100].sort_values('n_unique_stock_id')
# Out:
#        item_id  n_empty_stock_id  n_stock_id  n_unique_stock_id
# 16353  1246002                 1        1552                101
# 27192     2050                 1         888                101
# 4137   1993466                 0        6391                101
# 11271  1351801                 1        3032                101
# 13371  1875390                 1        2604                101
# ...        ...               ...         ...                ...
# 5912    531166                 0       74496                768
# 20108  1646173                 1       14415                769
# 4218   2660430                 0      124600               1405
# 44332  1428885                 1      230724               1633
# 29384  4024595                 0        1960               1960
#
# [456 rows x 4 columns]

# %%
engine = create_engine("mysql://wspider:wspider00!q@133.186.143.65:3306/wspider", connect_args={'connect_timeout': 10000})
colt_item_df = pd.read_sql_query("SELECT * FROM MWS_COLT_ITEM WHERE ID = %s" % '1428885', engine)

# %%
colt_item_df
# Out:
#         ID     GOODS_NUM   ITEM_NUM                              GOODS_NAME                                       GOODS_CATE BRAND_NAME  RELEASE_DT COLLECT_DAY SELL_CLOSE_DT ORG_MAFT_DT     MAFT_DT MAFT_ORIGIN   COLLECT_SITE PRICE_STD_CODE  PRICE  SITE_PRICE COLOR_OPTION SIZE_OPTION STYLE_OPTION GIFT_OPTION OPTION                                        COLLECT_URL  BEST_ITEM_YN BEST_ITEM_REG_DAY  SITE_NAME MATERIALS DESCR                                           ADD_INFO DETAIL_INFO TAG SIZE_FIT INGREDIENTS VOLUME TYPE                                            ORG_URL TRUST_SELLER  STORE_COLLECT_DATA_ID USE_WAY AVG_POINT  TOTAL_EVAL_CNT     STOCK_DETECT_DT  STOCK_CHANGE_YN  STATUS              REG_DT  REG_ID              UPT_DT  UPT_ID
# ...

# %%
sample = get_tables_from_goodsNum('2641066', engine)

plt.imshow(sample['image'])

# %%
qgrid.show_grid(sample['colt_item_ivt_df'], show_toolbar=True)
# Out:
# QgridWidget(grid_options={'enableTextSelectionOnCells': True, 'editable': True, 'explicitInitialization': True, 'minVisibleRows': 8, 'enableColumnReorder': False, 'defaultColumnWidth': 150, 'maxVisibleRows': 15, 'fullWidthRows': True, 'rowHeight': 28, 'autoEdit': False, 'syncColumnCellResize': True, 'forceFitColumns': True}, precision=5, show_toolbar=True)

# %%
# Out:
#         ID  GOODS_NUM    ITEM_NUM                                         GOODS_NAME                                         GOODS_CATE BRAND_NAME  RELEASE_DT COLLECT_DAY SELL_CLOSE_DT ORG_MAFT_DT     MAFT_DT MAFT_ORIGIN          COLLECT_SITE PRICE_STD_CODE  PRICE SITE_PRICE COLOR_OPTION SIZE_OPTION STYLE_OPTION GIFT_OPTION    OPTION                                        COLLECT_URL  BEST_ITEM_YN BEST_ITEM_REG_DAY SITE_NAME                              MATERIALS DESCR                                           ADD_INFO DETAIL_INFO TAG SIZE_FIT INGREDIENTS VOLUME TYPE                                            ORG_URL            TRUST_SELLER  STORE_COLLECT_DATA_ID USE_WAY AVG_POINT  TOTAL_EVAL_CNT     STOCK_DETECT_DT  STOCK_CHANGE_YN  STATUS              REG_DT  REG_ID              UPT_DT  UPT_ID
# ...

# %%
engine = create_engine("mysql://wspider:wspider00!q@133.186.143.65:3306/wspider", connect_args={'connect_timeout': 10000})
sample = get_tables_from_goodsNum('1428885', engine)
plt.imshow(sample['image'])

# %%
qgrid.show_grid(sample['colt_item_ivt_df'], show_toolbar=True)
# Out:
# QgridWidget(grid_options={'enableTextSelectionOnCells': True, 'editable': True, 'explicitInitialization': True, 'minVisibleRows': 8, 'enableColumnReorder': False, 'defaultColumnWidth': 150, 'maxVisibleRows': 15, 'fullWidthRows': True, 'rowHeight': 28, 'autoEdit': False, 'syncColumnCellResize': True, 'forceFitColumns': True}, precision=5, show_toolbar=True)

# %%
sample['colt_item_ivt_df']['OPTION'].unique()
# Out:
# array(['BLK(\xeb\xb8\x94\xeb\x9e\x99)',
#        'CMG(\xea\xb7\xb8\xeb\xa0\x88\xec\x9d\xb4)',
#        'NVY(\xeb\x84\xa4\xec\x9d\xb4\xeb\xb9\x84)'], dtype=object)

# %%
len(sample['colt_item_ivt_df']['COLOR_OPTION'].unique())
# Out:
# 2

# %%
sns.boxplot(x='SIZE_OPTION', y='STOCK_AMOUNT', data=sample['colt_item_ivt_df'])

# %%
engine = create_engine("mysql://wspider:wspider00!q@133.186.143.65:3306/wspider", connect_args={'connect_timeout': 10000})

stmt = "SELECT ITEM_ID FROM MWS_COLT_ITEM_IVT GROUP BY ITEM_ID"

pd.read_sql_query(stmt, engine)

# %%
engine = create_engine("mysql://wspider:wspider00!q@133.186.143.65:3306/wspider", connect_args={'connect_timeout': 10000})
pd.read_sql_query("SELECT * FROM MWS_COLT_ITEM_IVT LIMIT 3", engine)
# Out:
#    ID  ITEM_ID     STOCK_ID COLOR_OPTION SIZE_OPTION STYLE_OPTION GIFT_OPTION OPTION  STOCK_AMOUNT  ADD_PRICE COLLECT_DAY  REG_ID              REG_DT
# 0   1        1  26824625001           블랙          55         None        None  블랙/55           931          0    20170801  SERVER 2017-08-01 16:04:32
# 1   2        1  26824625002           블랙          66         None        None  블랙/66           880          0    20170801  SERVER 2017-08-01 16:04:32
# 2   3        1  26824625003           블랙          77         None        None  블랙/77           389          0    20170801  SERVER 2017-08-01 16:04:32

# %%
pd.DataFrame(stock_id_info_lst)
# Out:
#      item_id  n_empty_stock_id  n_stock_id  n_unique_stock_id
# 0          1                 0         329                  3
# 1          2                 0         402                  3
# 2          3                 0         502                  4
# 3          4                 0         301                  3
# 4          5                 0         376                  4
# ..       ...               ...         ...                ...
# 767      738                 0          95                  3
# 768      708                 1         469                 37
# 769      926                 1          16                  3
# 770      765                 1           2                  1
# 771      827                 0         147                  1
#
# [772 rows x 4 columns]

# %%
mp_worker(1)
mp_worker(2)

# %%
stock_info_lst
# Out:
# []

# %%
stock_info_lst
# Out:
# []

# %%
stock_info_lst
# Out:
# [{'item_id': 900, 'n_empty_stock_id': 1, 'n_unique_stock_id': 4},
#  {'item_id': 900,
#   'n_empty_stock_id': 1,
#   'n_stock_id': 138,
#   'n_unique_stock_id': 4}]

# %%
unique_stock_ids
# Out:
# array(['', '7567388617275247791', '3793086964269101981',
#        '2749946024175646118'], dtype=object)

# %%
# Out:
# 1

# %%
sample_item_1000.head()
# Out:
#          ID  ITEM_ID STOCK_ID COLOR_OPTION SIZE_OPTION STYLE_OPTION GIFT_OPTION OPTION  STOCK_AMOUNT  ADD_PRICE COLLECT_DAY  REG_ID              REG_DT
# 0      4702     1000                    기타        FREE         None        None                  999          0    20170801  SERVER 2017-08-01 16:07:33
# 1  16066192     1000                    기타        FREE         None        None                  996          0    20170804  SERVER 2017-08-04 12:04:09
# 2  28303162     1000                    기타        FREE         None        None                  995          0    20170805  SERVER 2017-08-05 08:05:37
# 3  40440072     1000                    기타        FREE         None        None                  994          0    20170806  SERVER 2017-08-06 09:35:11
# 4  52820207     1000                    기타        FREE         None        None                  993          0    20170807  SERVER 2017-08-07 10:10:41
