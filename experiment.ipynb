# %%
from util import *
#-*- coding: utf-8 -*-
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
engine = create_engine("mysql://wspider:wspider00!q@133.186.143.65:3306/wspider",
                           connect_args={'connect_timeout': 10000})

# %%
data = pd.read_sql_query("SELECT * FROM MWS_COLT_ITEM LIMIT 3" , engine)

# %%
data.ID.values
# Out:
# array([1, 2, 3])

# %%
for id in data.ID.values:
    image_df = pd.read_sql_query("SELECT * FROM MWS_COLT_IMAGE WHERE ITEM_ID = %s" % id, engine)
    print(image_df['GOODS_IMAGE'][0])

# %%
pd.read_sql_query("SELECT * FROM MWS_COLT_IMAGE WHERE ITEM_ID = %s" % '2', engine)
# Out:
#    ID  ITEM_ID                                        GOODS_IMAGE          FILE_PATH             OPTION  SEQ                HASH  STATUS              REG_DT              UPT_DT
# 0   2        2  http://image.gsshop.com/image/26/82/26824626_L...  /GSSHOP/2/0/2.jpg  67073096550953918    1 -709455420029072118       1 2017-08-01 16:04:32 2017-08-28 15:51:00

# %%
pd.read_sql_query("SELECT * FROM MWS_COLT_IMAGE WHERE ITEM_ID = %s" % '2', engine)['GOODS_IMAGE'][0]
# Out:
# 'http://image.gsshop.com/image/26/82/26824626_L1.jpg'

# %%
resp = urllib.urlopen('http://image.gsshop.com/image/26/82/26824626_L1.jpg')

# %%
resp
# Out:
# <addinfourl at 5113463584 whose fp = <socket._fileobject object at 0x130c8fad0>>

# %%
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

# %%
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# engine = create_engine("mysql://wspider:wspider00!q@133.186.143.65:3306/wspider",
#                            connect_args={'connect_timeout': 10000})

engine = create_engine("mysql://wspidermr:wspidermr00!q@133.186.134.155:3306/lf-bigdata-real-5",
                           connect_args={'connect_timeout': 10000})

# %%
data_answer = pd.read_sql_query("SELECT * FROM MLF_GOODS_ANSWER" , engine)

# %%
data_answer = data_answer[['GOODS_NO', 'CATE_CODE3']]

# %%
data_answer.head(20)
# Out:
#     GOODS_NO CATE_CODE3
# 0    4764804     WF1204
# 1    4764805     WF0902
# 2    4764808     WF0902
# 3    4764809     WF0699
# 4    4764810     WF0699
# ..       ...        ...
# 15   4764852     WF0902
# 16   4764856     WF0902
# 17   4764857     WF0902
# 18   4764858     WF0902
# 19   4764860     WF0902
#
# [20 rows x 2 columns]

# %%
# pd.read_sql_query("SELECT * FROM MLF_IMAGE LIMIT 3" , engine)

# %%
data_image = pd.read_sql_query("SELECT GOODS_NO, IMAGE_URL FROM MLF_IMAGE" , engine)

# %%
data_image = data_image.reset_index(drop=True)

# %%
data_image.head()
# Out:
#                                            IMAGE_URL  GOODS_NO
# 0  http://image.gsshop.com/image/26/82/26825197_L...   4764797
# 1  http://image.gsshop.com/image/26/82/26824627_L...   4764800
# 2  http://image.gsshop.com/image/26/82/26825223_L...   4764801
# 3  http://image.gsshop.com/image/26/82/26825131_L...   4764793
# 4  http://image.gsshop.com/image/25/63/25635525_L...   4764814

# %%
data_answer_image = pd.merge(data_answer, data_image, how='left', left_on=['GOODS_NO'], right_on=['GOODS_NO'])

# %%
data_answer_image = data_answer_image.groupby("GOODS_NO").first()

# %%
data_answer_image['GOODS_NO'] = data_answer_image.index

# %%
data_answer_image.head()
# Out:
#          CATE_CODE3                                          IMAGE_URL  GOODS_NO
# GOODS_NO
# 4764804      WF1204  http://image.gsshop.com/image/26/12/26125249_L...   4764804
# 4764805      WF0902  http://image.gsshop.com/image/25/11/25112401_L...   4764805
# 4764808      WF0902  http://image.gsshop.com/image/26/12/26125243_L...   4764808
# 4764809      WF0699  http://image.gsshop.com/image/26/76/26766819_L...   4764809
# 4764810      WF0699  http://image.gsshop.com/image/25/92/25920999_L...   4764810

# %%
data_category = pd.read_sql_query("SELECT * FROM MLF_CATEGORY" , engine)

# %%
data_category.head()
# Out:
#    CATE_NO  UPPER_CATE_NO CATE_NAME  DEPTH CODE1 CODE2 CODE3 CODE4 CODE5  STATUS CATE_NAMES  LEAF              REG_DT
# 0        0              0       미분류      1    99                               1        미분류     0 2017-08-29 11:34:48
# 1        1              0      남성의류      1    WM                               1       남성의류     0 2017-08-29 11:34:48
# 2        2              0      여성의류      1    WF                               1       여성의류     0 2017-08-29 11:34:48
# 3        3              0    유니섹스의류      1    WU                               1     유니섹스의류     0 2017-08-29 11:34:48
# 4        4              0      키즈의류      1    WK                               1       키즈의류     0 2017-08-29 11:34:48

# %%
data_category = data_category[['CODE3', 'CATE_NAMES']]

# %%
data_category.head()
# Out:
#   CODE3 CATE_NAMES
# 0              미분류
# 1             남성의류
# 2             여성의류
# 3           유니섹스의류
# 4             키즈의류

# %%
data_answer_image_category = pd.merge(data_answer_image, data_category, how='left', left_on=["CATE_CODE3"], right_on=["CODE3"])

# %%
data_answer_image_category.head()
# Out:
#   CATE_CODE3                                          IMAGE_URL  GOODS_NO   CODE3       CATE_NAMES
# 0     WF1204  http://image.gsshop.com/image/26/12/26125249_L...   4764804  WF1204       여성의류>팬츠>배기
# 1     WF0902  http://image.gsshop.com/image/25/11/25112401_L...   4764805  WF0902  여성의류>티셔츠>기타 티셔츠
# 2     WF0902  http://image.gsshop.com/image/26/12/26125243_L...   4764808  WF0902  여성의류>티셔츠>기타 티셔츠
# 3     WF0699  http://image.gsshop.com/image/26/76/26766819_L...   4764809  WF0699    여성의류>블라우스>미분류
# 4     WF0699  http://image.gsshop.com/image/25/92/25920999_L...   4764810  WF0699    여성의류>블라우스>미분류

# %%
del data_answer_image_category['CATE_CODE3']

# %%
# pickle.dump(data_answer_image_category, open("data/data_answer_image_category.pkl", "wb"))

# %%
# pickle.dump(data_answer_image_category, open("data/data_answer_image_category.pkl", "wb"))

# %%
data_answer_image_category['STATUS'] = "waiting"

# %%
data_answer_image_category.head()
# Out:
#                                            IMAGE_URL  GOODS_NO   CODE3       CATE_NAMES   STATUS
# 0  http://image.gsshop.com/image/26/12/26125249_L...   4764804  WF1204       여성의류>팬츠>배기  waiting
# 1  http://image.gsshop.com/image/25/11/25112401_L...   4764805  WF0902  여성의류>티셔츠>기타 티셔츠  waiting
# 2  http://image.gsshop.com/image/26/12/26125243_L...   4764808  WF0902  여성의류>티셔츠>기타 티셔츠  waiting
# 3  http://image.gsshop.com/image/26/76/26766819_L...   4764809  WF0699    여성의류>블라우스>미분류  waiting
# 4  http://image.gsshop.com/image/25/92/25920999_L...   4764810  WF0699    여성의류>블라우스>미분류  waiting

# %%
tmp2 = pd.read_sql_query("SELECT * FROM MLF_GOODS_CATE" , engine)

# %%
MLF_GOODS = pd.read_sql_query("SELECT GOODS_NO, GOODS_NAME, URL FROM MLF_GOODS" , engine)

# %%
data_answer_image_category.head()
# Out:
#                                            IMAGE_URL  GOODS_NO   CODE3       CATE_NAMES   STATUS
# 0  http://image.gsshop.com/image/26/12/26125249_L...   4764804  WF1204       여성의류>팬츠>배기  waiting
# 1  http://image.gsshop.com/image/25/11/25112401_L...   4764805  WF0902  여성의류>티셔츠>기타 티셔츠  waiting
# 2  http://image.gsshop.com/image/26/12/26125243_L...   4764808  WF0902  여성의류>티셔츠>기타 티셔츠  waiting
# 3  http://image.gsshop.com/image/26/76/26766819_L...   4764809  WF0699    여성의류>블라우스>미분류  waiting
# 4  http://image.gsshop.com/image/25/92/25920999_L...   4764810  WF0699    여성의류>블라우스>미분류  waiting

# %%
data_org_cate_name = tmp2[['GOODS_NO', 'ORG_CATE_NAME']]

# %%
# pd.merge(data_answer_image, data_category, how='left', left_on=["CATE_CODE3"], right_on=["CODE3"])

data_answer_image_category_org = pd.merge(data_answer_image_category, data_org_cate_name, how='left', left_on=["GOODS_NO"], right_on=["GOODS_NO"])

# %%
data_answer_image_category_org_mlf = pd.merge(data_answer_image_category_org, MLF_GOODS, how='left', left_on=["GOODS_NO"], right_on=["GOODS_NO"])

# %%
data_answer_image_category_org_mlf.head()
# Out:
#                                            IMAGE_URL  GOODS_NO   CODE3       CATE_NAMES   STATUS                ORG_CATE_NAME                 GOODS_NAME                                              URL
# 0  http://image.gsshop.com/image/26/12/26125249_L...   4764804  WF1204       여성의류>팬츠>배기  waiting  패션의류/속옷>여성의류>바지/팬츠>배기/통/와이드        [보니알렉스] 와이드 팬츠 3종택1  http://www.gsshop.com/prd/prd.gs?prdid=26125249
# 1  http://image.gsshop.com/image/25/11/25112401_L...   4764805  WF0902  여성의류>티셔츠>기타 티셔츠  waiting    패션의류/속옷>여성의류>티셔츠>라운드넥/브이넥  [리차드차이] 스카프넥 크롭티 ECTZ720C  http://www.gsshop.com/prd/prd.gs?prdid=25112401
# 2  http://image.gsshop.com/image/26/12/26125243_L...   4764808  WF0902  여성의류>티셔츠>기타 티셔츠  waiting    패션의류/속옷>여성의류>티셔츠>라운드넥/브이넥          리차드차이 린넨 티셔츠 3종택1  http://www.gsshop.com/prd/prd.gs?prdid=26125243
# ...

# %%
def get_images():
    

    df = data_answer_image_category[data_answer_image_category.STATUS != 'done']
    return df.head(10).T.to_dict().values()

# %%
#get_images()

# %%
tmp_gen
# Out:
# <generator object get_images at 0x25d173f50>

# %%
tmp = data_answer_image_category

# %%
tmp = pickle.load(open("data/data_answer_image_category.pkl", "rb"))

# %%
tmp['STATUS'] = 'waiting'

# %%
tmp['CATE_NAMES'][0]
# Out:
# '\xbf\xa9\xbc\xba\xc0\xc7\xb7\xf9>\xc6\xd2\xc3\xf7>\xb9\xe8\xb1\xe2'

# %%
print(a)

# %%
from pymongo import MongoClient
import json

# %%
client = MongoClient("mongodb://mongo-191809ff-1.b3d823aa.cont.dockerapp.io:32770")

# %%
db = client.epopcon

# %%
list(db.products.find().limit(3))
# Out:
# [{u'CATE_NAMES': u'\uc720\ub2c8\uc139\uc2a4\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WU0204',
#   u'GOODS_NAME': u'[\ud589\ud150]\ub0a8\uc5ec\uacf5\uc6a9 \ubc99\ucee4 \ub2e4\uc6b4\uc790\ucf13(10090-213-802-48)',
#   u'GOODS_NO': 10702464,
#   u'IMAGE_URL': u'http://image.lotte.com/goods/41/92/60/54/4/454609241_1_500.jpg',
#   u'ORG_CATE_NAME': u'\uc601\ud50c\ub77c\uc790 > \uc9c4/\uc720\ub2c8\uc139\uc2a4 > \uc810\ud37c > \ud328\ub529/\ub2e4\uc6b4\uc810\ud37c',
#   u'STATUS': u'1',
#   u'URL': u'http://www.lotte.com/goods/viewGoodsDetail.lotte?goods_no=454609241',
#   u'_id': ObjectId('5a6ac541160cd74183c0be14')},
#  {u'CATE_NAMES': u'\uc5ec\uc131\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WF0204',
#   u'GOODS_NAME': u'[\uc5d0\uc787\uc138\ucee8\uc988] \ube14\ub799 \ud6c4\ub4dc \ub2e4\uc6b4 \ud328\ub529 (167838SY15)',
#   u'GOODS_NO': 10702465,
# ...

# %%
# db.products_test.insert_many(list(db.products.find().limit(3)))

# %%
list(db.products_test.find())
# Out:
# [{u'CATE_NAMES': u'\uc720\ub2c8\uc139\uc2a4\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WU0204',
#   u'GOODS_NAME': u'[\ud589\ud150]\ub0a8\uc5ec\uacf5\uc6a9 \ubc99\ucee4 \ub2e4\uc6b4\uc790\ucf13(10090-213-802-48)',
#   u'GOODS_NO': 10702464,
#   u'IMAGE_URL': u'http://image.lotte.com/goods/41/92/60/54/4/454609241_1_500.jpg',
#   u'ORG_CATE_NAME': u'\uc601\ud50c\ub77c\uc790 > \uc9c4/\uc720\ub2c8\uc139\uc2a4 > \uc810\ud37c > \ud328\ub529/\ub2e4\uc6b4\uc810\ud37c',
#   u'STATUS': u'1',
#   u'URL': u'http://www.lotte.com/goods/viewGoodsDetail.lotte?goods_no=454609241',
#   u'_id': ObjectId('5a6ac541160cd74183c0be14')},
#  {u'CATE_NAMES': u'\uc5ec\uc131\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WF0204',
#   u'GOODS_NAME': u'[\uc5d0\uc787\uc138\ucee8\uc988] \ube14\ub799 \ud6c4\ub4dc \ub2e4\uc6b4 \ud328\ub529 (167838SY15)',
#   u'GOODS_NO': 10702465,
# ...

# %%
list(db.products_test.find())
# Out:
# [{u'CATE_NAMES': u'\uc720\ub2c8\uc139\uc2a4\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WU0204',
#   u'GOODS_NAME': u'[\ud589\ud150]\ub0a8\uc5ec\uacf5\uc6a9 \ubc99\ucee4 \ub2e4\uc6b4\uc790\ucf13(10090-213-802-48)',
#   u'GOODS_NO': 10702464,
#   u'IMAGE_URL': u'http://image.lotte.com/goods/41/92/60/54/4/454609241_1_500.jpg',
#   u'ORG_CATE_NAME': u'\uc601\ud50c\ub77c\uc790 > \uc9c4/\uc720\ub2c8\uc139\uc2a4 > \uc810\ud37c > \ud328\ub529/\ub2e4\uc6b4\uc810\ud37c',
#   u'STATUS': u'1',
#   u'URL': u'http://www.lotte.com/goods/viewGoodsDetail.lotte?goods_no=454609241',
#   u'_id': ObjectId('5a6ac541160cd74183c0be14')},
#  {u'CATE_NAMES': u'\uc5ec\uc131\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WF0204',
#   u'GOODS_NAME': u'[\uc5d0\uc787\uc138\ucee8\uc988] \ube14\ub799 \ud6c4\ub4dc \ub2e4\uc6b4 \ud328\ub529 (167838SY15)',
#   u'GOODS_NO': 10702465,
# ...

# %%
good_nos = [10702464]
status = '2'
username = 'minsu'
result = db.products_test.update_many({'GOODS_NO': {'$in': good_nos}}, {'$set': {'STATUS': status, 'USERNAME': username}})
# products

# %%
db.products_test.update_many({}, {'$set': {'USERNAME': 'TEST'}})

# %%
result.raw_result
# Out:
# {u'n': 1, u'nModified': 1, u'ok': 1.0, 'updatedExisting': True}

# %%
list(db.products.find({'USERNAME': 'minsu'}))
# Out:
# [{u'CATE_NAMES': u'\ub0a8\uc131\uc7a1\ud654>\ubbf8\ubd84\ub958>\ubbf8\ubd84\ub958',
#   u'CODE3': u'EM9999',
#   u'GOODS_NAME': u'[\ud558\ud504\ud074\ub7fd/BASSO homme]\uacac100 \ub808\ub4dc \uae30\ud558\ud559 \ud328\ud134 \ub125\ud0c0\uc774 (WSP3A..',
#   u'GOODS_NO': 7658408,
#   u'IMAGE_URL': u'http://image.gsshop.com/image/26/78/26786863_L1.jpg',
#   u'ORG_CATE_NAME': u'\ud328\uc158\uc758\ub958/\uc18d\uc637>\ud558\ud504\ud074\ub7fd>\ub0a8\uc131\uc815\uc7a5\xb7\uce90\uc8fc\uc5bc>\ud328\uc158\uc18c\ud488',
#   u'STATUS': u'-1',
#   u'URL': u'http://www.gsshop.com/prd/prd.gs?prdid=26786863',
#   u'USERNAME': u'minsu',
#   u'_id': ObjectId('5a6ac541160cd74183c1122c')},
#  {u'CATE_NAMES': u'\uc5ec\uc131\uc6a9\ud488>\uc2a4\ud3ec\uce20\uc6a9\ud488>\uc218\uc601',
#   u'CODE3': u'UF0301',
#   u'GOODS_NAME': u'[\uc544\ub808\ub098] \uc5ec\uc131 \uc77c\ubc18 \uc6d0\ud53c\uc2a4 \uc218\uc601\ubcf5 (ATBPL05) LIM',
#   u'GOODS_NO': 7658434,
# ...

# %%
list(db.products.find().limit(100))
# Out:
# [{u'CATE_NAMES': u'\uc720\ub2c8\uc139\uc2a4\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WU0204',
#   u'GOODS_NAME': u'[\ud589\ud150]\ub0a8\uc5ec\uacf5\uc6a9 \ubc99\ucee4 \ub2e4\uc6b4\uc790\ucf13(10090-213-802-48)',
#   u'GOODS_NO': 10702464,
#   u'IMAGE_URL': u'http://image.lotte.com/goods/41/92/60/54/4/454609241_1_500.jpg',
#   u'ORG_CATE_NAME': u'\uc601\ud50c\ub77c\uc790 > \uc9c4/\uc720\ub2c8\uc139\uc2a4 > \uc810\ud37c > \ud328\ub529/\ub2e4\uc6b4\uc810\ud37c',
#   u'STATUS': u'1',
#   u'URL': u'http://www.lotte.com/goods/viewGoodsDetail.lotte?goods_no=454609241',
#   u'USERNAME': u'',
#   u'_id': ObjectId('5a6ac541160cd74183c0be14')},
#  {u'CATE_NAMES': u'\uc5ec\uc131\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WF0204',
#   u'GOODS_NAME': u'[\uc5d0\uc787\uc138\ucee8\uc988] \ube14\ub799 \ud6c4\ub4dc \ub2e4\uc6b4 \ud328\ub529 (167838SY15)',
#   u'GOODS_NO': 10702465,
# ...

# %%
a = tmp.T.to_dict()

# %%
records = json.loads(data_answer_image_category_org_mlf.T.to_json()).values()

# %%
records[1:3]
# Out:
# [{u'CATE_NAMES': u'\uc5ec\uc131\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WF0204',
#   u'GOODS_NAME': u'[\uc5d0\uc787\uc138\ucee8\uc988] \ube14\ub799 \ud6c4\ub4dc \ub2e4\uc6b4 \ud328\ub529 (167838SY15)',
#   u'GOODS_NO': 10702465,
#   u'IMAGE_URL': u'http://image.gsshop.com/image/28/39/28392457_L1.jpg',
#   u'ORG_CATE_NAME': u'\ud328\uc158\uc758\ub958/\uc18d\uc637>\ub514\uc790\uc774\ub108\uc0f5>\ub0a8\uc131 \uc758\ub958>\uc790\ucf13/\ucf54\ud2b8/\ud328\ub529',
#   u'STATUS': u'waiting',
#   u'URL': u'http://www.gsshop.com/prd/prd.gs?prdid=28392457'},
#  {u'CATE_NAMES': u'\uc5ec\uc131\uc758\ub958>\uc2a4\uc6e8\ud130>\ud3f4\ub77c\ub2c8\ud2b8',
#   u'CODE3': u'WF0804',
#   u'GOODS_NAME': u'[\ud074\ub9ad\uc564\ud37c\ub2c8]\ucf00\ub9b0 \uaf48\ubc30\uae30 \ubc18\ud3f4\ub77c\ub2c8\ud2b8/\ud130\ud2c0\ub125/\ub871\uc2a4\uc6e8\ud130/\uc2dc\ubcf4\ub9ac\uc9dc',
#   u'GOODS_NO': 10702472,
# ...

# %%
products = db.products

# %%
products.drop()

# %%
products.insert_many(records)
products.create_index('GOODS_NO')
# Out:
# u'GOODS_NO_1'

# %%
len(list(products.find({'STATUS':'progress'})))
# Out:
# 20

# %%
retrived_lst = get_products_lst()

# %%
#retrived_lst

# %%
GOODS_NOs = [item['GOODS_NO'] for item in retrived_lst]

# %%
GOODS_NOs
# Out:
# [4856655,
#  4856677,
#  4856555,
#  4856620,
#  4856465,
#  4856535,
#  4856643,
#  4856653,
#  4856629,
#  4856630,
#  9955515,
#  9955509,
#  6849178,
#  9955525,
#  9955520,
#  5076652,
#  5076585,
#  5076548,
#  5076520,
#  5076582]

# %%
update_status('done', GOODS_NOs)

# %%
def get_products_lst(n=20):
    retrived_lst = list(products.find({'STATUS': 'waiting'}).limit(n))
    return retrived_lst
def update_status(status, good_nos):
    products.update_many({'GOODS_NO': {'$in': good_nos}}, {'$set': {'STATUS': status}})

# %%
list(products.find({'STATUS': '-1"}))
# Out:
# []

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://mongo-191809ff-1.b3d823aa.cont.dockerapp.io:32770")

# %%
client.database_names()
# Out:
# [u'admin', u'coinone', u'config', u'epopcon', u'local']

# %%
db_epopcon = client.epopcon

# %%
lst = list(db_epopcon.products.find().limit(10))

# %%
lst
# Out:
# [{u'CATE_NAMES': u'\uc720\ub2c8\uc139\uc2a4\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WU0204',
#   u'GOODS_NAME': u'[\ud589\ud150]\ub0a8\uc5ec\uacf5\uc6a9 \ubc99\ucee4 \ub2e4\uc6b4\uc790\ucf13(10090-213-802-48)',
#   u'GOODS_NO': 10702464,
#   u'IMAGE_URL': u'http://image.lotte.com/goods/41/92/60/54/4/454609241_1_500.jpg',
#   u'ORG_CATE_NAME': u'\uc601\ud50c\ub77c\uc790 > \uc9c4/\uc720\ub2c8\uc139\uc2a4 > \uc810\ud37c > \ud328\ub529/\ub2e4\uc6b4\uc810\ud37c',
#   u'STATUS': u'1',
#   u'URL': u'http://www.lotte.com/goods/viewGoodsDetail.lotte?goods_no=454609241',
#   u'USERNAME': u'',
#   u'_id': ObjectId('5a6ac541160cd74183c0be14')},
#  {u'CATE_NAMES': u'\uc5ec\uc131\uc758\ub958>\uc810\ud37c/\uc544\uc6b0\ud130>\ub2e4\uc6b4\uc810\ud37c',
#   u'CODE3': u'WF0204',
#   u'GOODS_NAME': u'[\uc5d0\uc787\uc138\ucee8\uc988] \ube14\ub799 \ud6c4\ub4dc \ub2e4\uc6b4 \ud328\ub529 (167838SY15)',
#   u'GOODS_NO': 10702465,
# ...

# %%
df = pd.DataFrame(lst)

# %%
df.head()
# Out:
#            CATE_NAMES   CODE3                          GOODS_NAME  GOODS_NO                                          IMAGE_URL                     ORG_CATE_NAME STATUS                                                URL                       _id
# 0  유니섹스의류>점퍼/아우터>다운점퍼  WU0204  [행텐]남여공용 벙커 다운자켓(10090-213-802-48)  10702464  http://image.lotte.com/goods/41/92/60/54/4/454...      영플라자 > 진/유니섹스 > 점퍼 > 패딩/다운점퍼      1  http://www.lotte.com/goods/viewGoodsDetail.lot...  5a6ac541160cd74183c0be14
# 1    여성의류>점퍼/아우터>다운점퍼  WF0204    [에잇세컨즈] 블랙 후드 다운 패딩 (167838SY15)  10702465  http://image.gsshop.com/image/28/39/28392457_L...      패션의류/속옷>디자이너샵>남성 의류>자켓/코트/패딩      1    http://www.gsshop.com/prd/prd.gs?prdid=28392457  5a6ac541160cd74183c0be15
# 2       여성의류>스웨터>폴라니트  WF0804   [클릭앤퍼니]케린 꽈배기 반폴라니트/터틀넥/롱스웨터/시보리짜  10702472  http://image.gsshop.com/image/28/54/28549642_L...  패션의류/속옷>트렌드의류>니트/가디건/조끼>터틀넥/폴라니트      1    http://www.gsshop.com/prd/prd.gs?prdid=28549642  5a6ac541160cd74183c0be16
# ...

# %%
engine = create_engine("mysql://wspidermr:wspidermr00!q@133.186.134.155:3306/lf-bigdata-real-5",
                           connect_args={'connect_timeout': 10000})

# %%
from sqlalchemy import MetaData, Table

# %%
from sqlalchemy.sql import table, column, select, update, insert
from sqlalchemy.orm import sessionmaker
# define meta information
metadata = MetaData(bind=engine)
mytable = Table('MLF_CATEGORY_LABELED', metadata, autoload=True)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
lst[0]['STATUS']
# Out:
# u'1'

# %%
# i = insert(mytable)
# i = i.values({'GOODS_NO': lst[1]['GOODS_NO'], 'STATUS': lst[1]['STATUS']})
# session.execute(i)ask_price1,ask_price2,ask_qty1,ask_qty2,bid_price1,bid_price2,bid_qty1,bid_qty2,currency,errorCode,first,high,last,low,result,timestamp,volume,yesterday_first,yesterday_high,yesterday_last,yesterday_low,yesterday_volume
# 72590,72600,49.1511,175.5696,72400,72360,29.0972,9.3200,qtum,0,72120,77360,72400,70430,success,1514819737,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72400,72360,29.0972,9.3200,qtum,0,72120,77360,72400,70430,success,1514819738,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72410,72400,66.7342,29.0972,qtum,0,72120,77360,72400,70430,success,1514819739,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72410,72400,66.7342,29.0972,qtum,0,72120,77360,72400,70430,success,1514819740,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72410,72400,66.7342,29.0972,qtum,0,72120,77360,72400,70430,success,1514819741,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72410,72400,66.7342,29.0972,qtum,0,72120,77360,72400,70430,success,1514819742,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72410,72400,66.7342,29.0972,qtum,0,72120,77360,72400,70430,success,1514819743,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72410,72400,66.7342,29.0972,qtum,0,72120,77360,72400,70430,success,1514819744,1048538.0962,72560,77360,73120,70430,1052842.0381
# 72500,72590,1.0000,49.1511,72410,72400,66.7342,29.0972,qtum,0,72090,77360,72400,70430,success,1514819745,1048533.8725,72560,77360,73120,70430,1052842.0381
# 72500,72590,1.0000,49.1511,72410,72400,66.7342,29.0972,qtum,0,72090,77360,72400,70430,success,1514819746,1048533.8725,72560,77360,73120,70430,1052842.0381
# 72500,72590,1.0000,49.1511,72410,72400,66.7342,29.0972,qtum,0,72090,77360,72400,70430,success,1514819747,1048533.8725,72560,77360,73120,70430,1052842.0381
# 72500,72590,1.0000,49.1511,72410,72400,66.7342,29.0972,qtum,0,72090,77360,72400,70430,success,1514819748,1048533.8725,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72410,72400,66.7342,29.0972,qtum,0,72090,77360,72500,70430,success,1514819749,1048534.8725,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72300,72280,72.3600,10.2000,qtum,0,72090,77360,72300,70430,success,1514819750,1048716.8977,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72300,72280,68.9600,10.2000,qtum,0,72090,77360,72300,70430,success,1514819751,1048720.2977,72560,77360,73120,70430,1052842.0381
# 72590,72600,49.1511,175.5696,72300,72280,68.9600,10.2000,qtum,0,72090,77360,72300,70430,success,1514819752,1048720.2977,72560,77360,73120,70430,1052842.0381
# 72580,72590,66.7342,152.6771,72300,72280,68.9600,10.2000,qtum,0,72090,77360,72300,70430,success,1514819753,1048720.2977,72560,77360,73120,70430,1052842.0381
# 72400,72580,1.0000,66.7342,72310,72300,14.8000,68.9600,qtum,0,72090,77360,72300,70430,success,1514819754,1048720.2977,72560,77360,73120,70430,1052842.0381
# 72400,72580,1.0000,66.7342,72310,72300,14.8000,83.7600,qtum,0,72090,77360,72300,70430,success,1514819755,1048720.2977,72560,77360,73120,70430,1052842.0381
# 72400,72580,1.0000,66.7342,72310,72300,14.8000,83.7600,qtum,0,72090,77360,72300,70430,success,1514819756,1048720.2977,72560,77360,73120,70430,1052842.0381

# %%
# Out:
#         GOODS_NO   STATUS
# 0       10702464        1
# 1       10702465        1
# 2       10702472        1
# 3       10702477       -1
# 4       10702429        1
# ...          ...      ...
# 364128  10047367  waiting
# 364129  10047370  waiting
# 364130  10047371  waiting
# 364131  10047404  waiting
# 364132  10047409  waiting
#
# [364133 rows x 2 columns]

# %%
df[['GOODS_NO', 'STATUS']].to_sql(con=engine, name='MLF_CATEGORY_LABELED', if_exists='replace', flavor='mysql')

# %%
df.loc[df.STATUS != 'waiting', ['GOODS_NO', 'STATUS']].to_sql(con=engine, name='MLF_CATEGORY_LABELED2', if_exists='replace', flavor='mysql')

# %%
db_epopcon.products.find({'USERNAME': 'Sam'}).count()
# Out:
# 2762
